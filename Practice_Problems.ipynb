# %% [markdown]
# 1. Frequency Classification
# Input:
# numbers = [4, 2, 4, 7, 2, 4, 9, 9, 9, 9, 5, 5, 5, 5, 5, 5, 8]
# Task:
# 1. Build a frequency dictionary.
# 2. Classify every distinct number:
#    - frequency 1 → "unique"
#    - frequency 2–3 → "rare"
#    - frequency 4–6 → "common"
#    - frequency > 6 → "frequent"
# 3. Produce a dictionary in the form {number: (frequency, classification)}.
# Expected:
# {2: (2, 'rare'), 4: (3, 'rare'), 7: (1, 'unique'), 9: (4, 'common'),
#  5: (6, 'common'), 8: (1, 'unique')}

# %%
i = int(input("Enter the Number: "))

# %% [markdown]
# 2. First Repeated vs First Unique
# Input:
# values = [7, 3, 5, 3, 9, 7, 11, 5, 13, 9]
# Task:
# Find:
# - the first value that appears more than once when scanning from left to right
# - the first value that appears exactly once when scanning from left to right
# Expected:
# first_repeated = 3
# first_unique = 11

# %%
l = [3,7,5,9,7,11,13,9,9]

# %%
def first_repeating_value(l):
    n = len(l)
    for i in range (n-1):   
        for j in range (i+1,n):
            if l[j]==l[i]:   
        print(f"The first value appears more than once when scanning from left to right is {left}.")


def first_unique(l):    
    left = 0
    n = len(l)
    for i in range (n):
        for j in range(i+1,n):
            if l[i]==l[j]:
                continue            
            else:
                left=l[i]       
print(f"The first value appears once when scanning from left to right is {left}.")

# %%
first_repeating_value(l)
first_unique(l)
# Out:
# The first value appears more than once when scanning from left to right is 3.
# The first value appears once when scanning from left to right is 3.

# %%
l = [7,3,7,5,9,7,11,13,9,9]

# %%
first_unique(l)
# Out:
# The first value appears once when scanning from left to right is 7.

# %%
def first_repeating_value(l):
    n = len(l)

    for i in range(n):
        for j in range(i + 1, n):
            if l[i] == l[j]:
                print(
                    f"The first value that appears more than once "
                    f"when scanning from left to right is {l[i]}."
                )
                return

    print("There is no repeating value.")

# %%
first_repeating_value(l)
# Out:
# The first value that appears more than once when scanning from left to right is 7.
